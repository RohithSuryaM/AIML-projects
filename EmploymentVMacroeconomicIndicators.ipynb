# %%
import DataProcessor as dp
import EDA as eda
import TimeSeriesForecasting as tsf
import MultipleLinearRegression as mlr
import Dashboard as db

# %%
file_path = 'EMPLOYMENT SITUATION IN INDIA - PER 1000 DISTRIBUTION OF USUALLY EMPLOYED vs Macroeconomic indicators.xlsx'

# %%
processed_data = dp.DataProcessor(file_path).run_pipeline()
processed_data
# Out:
# {'Rural Primary':     Year  PS-Male  ALL-Male  PS-Female  ALL-Female
#  0   1987   739.00    745.00    825.000     847.000
#  1   1989   716.00    717.00    800.000     814.000
#  2   1990   705.00    710.00    842.000     849.000
#  3   1991   749.50    752.00    858.625     862.625
#  4   1992   751.00    755.00    858.250     862.250
#  5   1993   739.00    741.00    847.000     862.000
#  6   1994   752.00    756.00    862.000     871.000
#  7   1995   746.00    748.00    854.000     868.000
#  8   1996   751.50    753.00    864.500     876.500
#  9   1997   753.25    755.00    870.250     880.750
#  10  1999   712.00    714.00    841.000     854.000
#  11  2000   688.00    690.00    812.000     818.000
#  12  2001   672.00    678.00    819.000     840.000
#  13  2002   682.00    685.75    832.250     847.750
#  14  2003   679.00    683.50    830.500     846.500
#  15  2004   662.00    665.00    814.000     833.000
#  16  2005   648.00    652.00    798.000     813.000
# ...

# %%
eda_results = eda.EDA(processed_data).run_pipeline()
eda_results
# Out:
# {'summary_statistics': {'Rural Primary':           PS-Male    ALL-Male   PS-Female  ALL-Female
#   count   26.000000   26.000000   26.000000   26.000000
#   mean   676.009615  663.932692  809.552885  819.168269
#   std     62.743943   86.664917   45.086087   50.187286
#   min    592.000000  491.000000  745.000000  711.000000
#   25%    600.250000  602.500000  756.000000  770.000000
#   50%    680.500000  684.625000  817.500000  837.500000
#   75%    739.000000  744.000000  845.750000  860.000000
#   max    753.250000  756.000000  870.250000  880.750000,
#   'Rural Secondary':           PS-Male    ALL-Male   PS-Female  ALL-Female
#   count   26.000000   26.000000   26.000000   26.000000
#   mean   156.721154  161.365385  114.115385  107.682692
#   std     45.280257   55.182118   28.108560   27.063218
#   min    104.000000  103.000000   76.000000   71.000000
#   25%    116.250000  115.750000   88.750000   83.000000
#   50%    147.250000  144.625000  110.000000  101.000000
# ...

# %%
tsf_results = tsf.TimeSeriesForecasting(processed_data).run_pipeline()
tsf_results
# Out:
# C:\Users\mural\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\mural\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\mural\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# C:\Users\mural\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
mlr_results = mlr.MultipleLinearRegression(processed_data).run_pipeline()
mlr_results
# Out:
# {'normal': {'Rural Primary': array([[-1.66082837e+01, -2.19930250e+01,  2.77583003e+01,
#           -1.88659300e+00],
#          [ 1.49933907e+05, -1.93916776e+05, -6.62950905e+03,
#            3.24614108e+02],
#          [ 1.34969081e+05, -1.74389830e+05, -5.23146126e+03,
#            3.67797872e+02],
#          [ 9.70944399e+02, -1.34650349e+03,  3.72310103e+01,
#           -3.70019671e+01],
#          [ 8.19361520e+02, -1.15221782e+03,  6.69623548e+01,
#           -6.99134179e+01]]),
#   'Rural Secondary': array([[ 3.76847214e+01,  8.90247798e+00,  7.32492484e+00,
#           -2.43331012e+01],
#          [-1.23458503e+05,  2.49365722e+05,  9.82378063e+04,
#           -1.23206482e+05],
#          [-1.15849979e+05,  2.27473910e+05,  8.51872402e+04,
#           -1.07467785e+05],
#          [-7.58220665e+02,  1.71131096e+03,  6.34821106e+02,
#           -8.35979615e+02],
#          [-5.82116554e+02,  1.42867454e+03,  5.66456647e+02,
#           -7.42767911e+02]]),
# ...

# %%
dashboard = db.Dashboard(processed_data,eda_results,tsf_results,mlr_results).run()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8083/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
